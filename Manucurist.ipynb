# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from requests import get
import requests
import json
from datetime import datetime

# %%
# loop all the page baby
def all_page_link(start_url):
    all_urls = []
    url = start_url
    while(url != None):            
        all_urls.append(url)
        soup = BeautifulSoup(requests.get(url).text,"html.parser")
        next_links = soup.find_all(class_='next')
        if (len(next_links) == 0):        
            url = None
        else:
            next_page = "https://www.manucurist.com/" + next_links[0].find('a').get('href')
            url = next_page
    return all_urls

# %%
link = all_page_link('https://www.manucurist.com/collections/vernis-green?page=1')

# %%
def scrapping(url,class_):

    response = requests.get(url)
    page_contents = response.text
    soup = BeautifulSoup(page_contents, 'html.parser')
    goodsoup = soup.find_all("div", {"class": class_})
    
    mydata=[]

    for soup in goodsoup:
        title = soup.find("div", {"class": 'grid-product__title'}).text
        category = soup.find("div", {"class": 'grid-product__type'}).text.strip()
        price = soup.find("div", {"class": 'grid-product__price'}).text.strip()
        stock = soup.find("div", {"class": 'product__inventory'}).text.strip()
        
        products_dict = {
        'title': title,
        'category': category,
        'price': price,
        'stock': stock,
        'datetime': datetime.now()}
        mydata.append(products_dict)
    
    return mydata

# %%
data=[]
for i in link:
    data.extend(scrapping(i,"grid-product__content"))
df = pd.DataFrame(data)

# %%
df['price']=df['price'].str.replace('€','')
df['price']=df['price'].str.replace(',','.')
df['stock']=df['stock'].str.replace(' en stock','')

# %%
df.to_csv('data.csv', index=None)

# %%
df
# Out:
#                                                title         category price  \
# 0                                        Shell Beige  Vernis à ongles   14
# 1                                          Navy Blue  Vernis à ongles   14
# 2                              Eau dissolvante Green  Vernis à ongles   14
# 3                                          Base Coat  Vernis à ongles   12
# 4                                           Top Coat  Vernis à ongles   12
# ..                                               ...              ...   ...
# 92   Trio set Green -  Dune & Aubergine & Poppy Seed  Vernis à ongles   32
# 93                      Flea Market Collection Green  Vernis à ongles   55
# 94  Trio set Green -  Dark Pansy & Terracotta & Dune  Vernis à ongles   32
# 95                    Duo Set Green - Khaki & Bronzé  Vernis à ongles   22
# 96        Trio set Green -  Khaki & Violeta & Bronzé  Vernis à ongles   32
#
#     stock                   datetime
# 0    4544 2022-09-28 10:18:38.138636
# 1    6086 2022-09-28 10:18:38.139632
# 2   15591 2022-09-28 10:18:38.139632
# 3    7974 2022-09-28 10:18:38.139632
# 4    4009 2022-09-28 10:18:38.139632
# ..    ...                        ...
# 92   2103 2022-09-28 10:18:38.844548
# 93  10914 2022-09-28 10:18:38.844548
# 94  19975 2022-09-28 10:18:38.845548
# 95  19991 2022-09-28 10:18:38.845548
# 96  19981 2022-09-28 10:18:38.846548
#
# [97 rows x 5 columns]

# %%
df
# Out:
#                                                title         category price  \
# 0                                        Shell Beige  Vernis à ongles   14
# 1                                          Navy Blue  Vernis à ongles   14
# 2                              Eau dissolvante Green  Vernis à ongles   14
# 3                                          Base Coat  Vernis à ongles   12
# 4                                           Top Coat  Vernis à ongles   12
# ..                                               ...              ...   ...
# 92   Trio set Green -  Dune & Aubergine & Poppy Seed  Vernis à ongles   32
# 93                      Flea Market Collection Green  Vernis à ongles   55
# 94  Trio set Green -  Dark Pansy & Terracotta & Dune  Vernis à ongles   32
# 95                    Duo Set Green - Khaki & Bronzé  Vernis à ongles   22
# 96        Trio set Green -  Khaki & Violeta & Bronzé  Vernis à ongles   32
#
#     stock
# 0    4550
# 1    6092
# 2   15639
# 3    8011
# 4    4061
# ..    ...
# 92   2104
# 93  10921
# 94  19979
# 95  19992
# 96  19982
#
# [97 rows x 4 columns]
